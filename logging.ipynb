# %% [markdown]
# https://www.tensorflow.org/versions/r0.11/tutorials/monitors/index.html

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import numpy as np

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
# Data sets
IRIS_TRAINING = "iris_training.csv"
IRIS_TEST = "iris_test.csv"

# Load datasets.
training_set = tf.contrib.learn.datasets.base.load_iris(data_path = IRIS_TRAINING)
test_set = tf.contrib.learn.datasets.base.load_iris(data_path = IRIS_TEST)

# %%
# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

# %%
validation_metrics = {"accuracy": tf.contrib.metrics.streaming_accuracy,
                      "precision": tf.contrib.metrics.streaming_precision,
                      "recall": tf.contrib.metrics.streaming_recall}
validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    test_set.data,
    test_set.target,
    every_n_steps=50)

# %%
# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[10, 20, 10],
                                            n_classes=3,
                                            model_dir="/tmp/iris_model",
                                            config=tf.contrib.learn.RunConfig(
                                                save_checkpoints_secs=1))
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# INFO:tensorflow:Using config: {'save_checkpoints_secs': 1, '_job_name': None, 'keep_checkpoint_max': 5, 'tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , 'num_ps_replicas': 0, '_is_chief': True, 'master': '', 'tf_random_seed': None, 'task': 0, 'save_summary_steps': 100, 'evaluation_master': '', 'cluster_spec': None, 'keep_checkpoint_every_n_hours': 10000}

# %%
# Fit model.
classifier.fit(x=training_set.data,
               y=training_set.target,
               steps=2000,
               monitors=[validation_monitor])
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Setting feature info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False)
# INFO:tensorflow:Setting targets info to TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 1.00653, step = 2
# INFO:tensorflow:Saving checkpoints for 2 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 2.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 2 step: accuracy = 0.166667, loss = 0.917489
# INFO:tensorflow:Validation (step 50): accuracy = 0.166667, loss = 0.917489, global_step = 2
# INFO:tensorflow:Saving checkpoints for 51 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 51.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 51 step: accuracy = 0.833333, loss = 0.326201
# INFO:tensorflow:Validation (step 100): accuracy = 0.833333, loss = 0.326201, global_step = 51
# INFO:tensorflow:Saving checkpoints for 101 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.1209, step = 102
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 101.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 101 step: accuracy = 0.933333, loss = 0.144241
# INFO:tensorflow:Validation (step 150): accuracy = 0.933333, loss = 0.144241, global_step = 101
# INFO:tensorflow:Saving checkpoints for 151 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 151.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 151 step: accuracy = 0.966667, loss = 0.0948614
# INFO:tensorflow:Validation (step 200): accuracy = 0.966667, loss = 0.0948614, global_step = 151
# INFO:tensorflow:Saving checkpoints for 201 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0780781, step = 202
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 201.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 201 step: accuracy = 0.966667, loss = 0.0823049
# INFO:tensorflow:Validation (step 250): accuracy = 0.966667, loss = 0.0823049, global_step = 201
# INFO:tensorflow:Saving checkpoints for 251 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 251.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 251 step: accuracy = 0.966667, loss = 0.0719176
# INFO:tensorflow:Validation (step 300): accuracy = 0.966667, loss = 0.0719176, global_step = 251
# INFO:tensorflow:Saving checkpoints for 301 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0668374, step = 302
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 301.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 301 step: accuracy = 0.966667, loss = 0.0683902
# INFO:tensorflow:Validation (step 350): accuracy = 0.966667, loss = 0.0683902, global_step = 301
# INFO:tensorflow:Saving checkpoints for 351 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 351.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 351 step: accuracy = 0.966667, loss = 0.0645064
# INFO:tensorflow:Validation (step 400): accuracy = 0.966667, loss = 0.0645064, global_step = 351
# INFO:tensorflow:Saving checkpoints for 401 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0610274, step = 402
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 401.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 401 step: accuracy = 0.966667, loss = 0.0625332
# INFO:tensorflow:Validation (step 450): accuracy = 0.966667, loss = 0.0625332, global_step = 401
# INFO:tensorflow:Saving checkpoints for 451 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 451.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 451 step: accuracy = 0.966667, loss = 0.0608448
# INFO:tensorflow:Validation (step 500): accuracy = 0.966667, loss = 0.0608448, global_step = 451
# INFO:tensorflow:Saving checkpoints for 501 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0573926, step = 502
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 501.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 501 step: accuracy = 0.933333, loss = 0.0597229
# INFO:tensorflow:Validation (step 550): accuracy = 0.933333, loss = 0.0597229, global_step = 501
# INFO:tensorflow:Saving checkpoints for 551 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 551.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 551 step: accuracy = 0.933333, loss = 0.0589022
# INFO:tensorflow:Validation (step 600): accuracy = 0.933333, loss = 0.0589022, global_step = 551
# INFO:tensorflow:Saving checkpoints for 601 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0547296, step = 602
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 601.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 601 step: accuracy = 0.933333, loss = 0.0582089
# INFO:tensorflow:Validation (step 650): accuracy = 0.933333, loss = 0.0582089, global_step = 601
# INFO:tensorflow:Saving checkpoints for 651 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 651.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 651 step: accuracy = 0.933333, loss = 0.0567713
# INFO:tensorflow:Validation (step 700): accuracy = 0.933333, loss = 0.0567713, global_step = 651
# INFO:tensorflow:Saving checkpoints for 701 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0524352, step = 702
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 701.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 701 step: accuracy = 0.933333, loss = 0.0572752
# INFO:tensorflow:Validation (step 750): accuracy = 0.933333, loss = 0.0572752, global_step = 701
# INFO:tensorflow:Saving checkpoints for 751 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 751.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 751 step: accuracy = 0.933333, loss = 0.0571857
# INFO:tensorflow:Validation (step 800): accuracy = 0.933333, loss = 0.0571857, global_step = 751
# INFO:tensorflow:Saving checkpoints for 801 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.05055, step = 802
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 801.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 801 step: accuracy = 0.933333, loss = 0.0559146
# INFO:tensorflow:Validation (step 850): accuracy = 0.933333, loss = 0.0559146, global_step = 801
# INFO:tensorflow:Saving checkpoints for 851 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 851.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 851 step: accuracy = 0.933333, loss = 0.0570626
# INFO:tensorflow:Validation (step 900): accuracy = 0.933333, loss = 0.0570626, global_step = 851
# INFO:tensorflow:Saving checkpoints for 901 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0485827, step = 902
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 901.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 901 step: accuracy = 0.966667, loss = 0.0561385
# INFO:tensorflow:Validation (step 950): accuracy = 0.966667, loss = 0.0561385, global_step = 901
# INFO:tensorflow:Saving checkpoints for 951 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 951.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 951 step: accuracy = 0.966667, loss = 0.0574637
# INFO:tensorflow:Validation (step 1000): accuracy = 0.966667, loss = 0.0574637, global_step = 951
# INFO:tensorflow:Saving checkpoints for 1001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0479755, step = 1002
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1001.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1001 step: accuracy = 0.933333, loss = 0.0572572
# INFO:tensorflow:Validation (step 1050): accuracy = 0.933333, loss = 0.0572572, global_step = 1001
# INFO:tensorflow:Saving checkpoints for 1051 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1051.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1051 step: accuracy = 0.933333, loss = 0.0574434
# INFO:tensorflow:Validation (step 1100): accuracy = 0.933333, loss = 0.0574434, global_step = 1051
# INFO:tensorflow:Saving checkpoints for 1101 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0467095, step = 1102
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1101.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1101 step: accuracy = 0.966667, loss = 0.0573851
# INFO:tensorflow:Validation (step 1150): accuracy = 0.966667, loss = 0.0573851, global_step = 1101
# INFO:tensorflow:Saving checkpoints for 1151 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1151.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1151 step: accuracy = 0.966667, loss = 0.0575148
# INFO:tensorflow:Validation (step 1200): accuracy = 0.966667, loss = 0.0575148, global_step = 1151
# INFO:tensorflow:Saving checkpoints for 1201 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0448429, step = 1202
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1201.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1201 step: accuracy = 0.966667, loss = 0.0576911
# INFO:tensorflow:Validation (step 1250): accuracy = 0.966667, loss = 0.0576911, global_step = 1201
# INFO:tensorflow:Saving checkpoints for 1251 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1251.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1251 step: accuracy = 0.966667, loss = 0.05861
# INFO:tensorflow:Validation (step 1300): accuracy = 0.966667, loss = 0.05861, global_step = 1251
# INFO:tensorflow:Saving checkpoints for 1301 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.044466, step = 1302
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1301.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1301 step: accuracy = 0.966667, loss = 0.0578572
# INFO:tensorflow:Validation (step 1350): accuracy = 0.966667, loss = 0.0578572, global_step = 1301
# INFO:tensorflow:Saving checkpoints for 1351 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1351.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1351 step: accuracy = 0.966667, loss = 0.0557337
# INFO:tensorflow:Validation (step 1400): accuracy = 0.966667, loss = 0.0557337, global_step = 1351
# INFO:tensorflow:Saving checkpoints for 1401 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0439005, step = 1402
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1401.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1401 step: accuracy = 0.966667, loss = 0.0581225
# INFO:tensorflow:Validation (step 1450): accuracy = 0.966667, loss = 0.0581225, global_step = 1401
# INFO:tensorflow:Saving checkpoints for 1451 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1451.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1451 step: accuracy = 0.966667, loss = 0.0578933
# INFO:tensorflow:Validation (step 1500): accuracy = 0.966667, loss = 0.0578933, global_step = 1451
# INFO:tensorflow:Saving checkpoints for 1501 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0424731, step = 1502
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1501.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1501 step: accuracy = 0.966667, loss = 0.0599727
# INFO:tensorflow:Validation (step 1550): accuracy = 0.966667, loss = 0.0599727, global_step = 1501
# INFO:tensorflow:Saving checkpoints for 1551 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1551.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1551 step: accuracy = 0.966667, loss = 0.0593332
# INFO:tensorflow:Validation (step 1600): accuracy = 0.966667, loss = 0.0593332, global_step = 1551
# INFO:tensorflow:Saving checkpoints for 1601 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0415103, step = 1602
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1601.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1601 step: accuracy = 0.966667, loss = 0.0608476
# INFO:tensorflow:Validation (step 1650): accuracy = 0.966667, loss = 0.0608476, global_step = 1601
# INFO:tensorflow:Saving checkpoints for 1651 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1651.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1651 step: accuracy = 0.966667, loss = 0.0594077
# INFO:tensorflow:Validation (step 1700): accuracy = 0.966667, loss = 0.0594077, global_step = 1651
# INFO:tensorflow:Saving checkpoints for 1701 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0413877, step = 1702
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1701.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1701 step: accuracy = 0.966667, loss = 0.0606072
# INFO:tensorflow:Validation (step 1750): accuracy = 0.966667, loss = 0.0606072, global_step = 1701
# INFO:tensorflow:Saving checkpoints for 1751 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1751.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1751 step: accuracy = 0.966667, loss = 0.059954
# INFO:tensorflow:Validation (step 1800): accuracy = 0.966667, loss = 0.059954, global_step = 1751
# INFO:tensorflow:Saving checkpoints for 1801 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0403603, step = 1802
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1801.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1801 step: accuracy = 0.966667, loss = 0.0614879
# INFO:tensorflow:Validation (step 1850): accuracy = 0.966667, loss = 0.0614879, global_step = 1801
# INFO:tensorflow:Saving checkpoints for 1851 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1851.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1851 step: accuracy = 0.966667, loss = 0.0609828
# INFO:tensorflow:Validation (step 1900): accuracy = 0.966667, loss = 0.0609828, global_step = 1851
# INFO:tensorflow:Saving checkpoints for 1901 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0393328, step = 1902
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1901.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1901 step: accuracy = 0.966667, loss = 0.0614127
# INFO:tensorflow:Validation (step 1950): accuracy = 0.966667, loss = 0.0614127, global_step = 1901
# INFO:tensorflow:Saving checkpoints for 1951 into /tmp/iris_model/model.ckpt.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 1951.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 1951 step: accuracy = 0.966667, loss = 0.0630495
# INFO:tensorflow:Validation (step 2000): accuracy = 0.966667, loss = 0.0630495, global_step = 1951
# INFO:tensorflow:Saving checkpoints for 2001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0388302.
# Estimator(params={'activation_fn': <function relu at 0x7f5b807d9f28>, 'n_classes': 3, 'enable_centered_bias': True, 'weight_column_name': None, 'hidden_units': [10, 20, 10], 'gradient_clip_norm': None, 'feature_columns': [_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)], 'dropout': None, 'num_ps_replicas': 0, 'optimizer': 'Adagrad'})

# %%
# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=test_set.data,
                                     y=test_set.target)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /tmp/iris_model
# INFO:tensorflow:Eval steps [0,inf) for training step 2001.
# INFO:tensorflow:Input iterator is exhausted.
# INFO:tensorflow:Saving evaluation summary for 2001 step: accuracy = 0.966667, loss = 0.061843
# WARNING:tensorflow:Calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Loading model from checkpoint: /tmp/iris_model/model.ckpt-2001-?????-of-00001.
# Accuracy: 0.966667
# Predictions: [1 2]
